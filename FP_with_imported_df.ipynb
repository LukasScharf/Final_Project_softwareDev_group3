# %% [markdown]
# ## Final project - same functions used on imported data from an excel-file
#
# Import the necessary modules:

# %%
import mapFunctions as mf
import plotFunctions as pf
import routingFunctions as rf
import pandas as pd
import osmnx as ox

# %% [markdown]
# ### Read the data (xlsx file)

# %%
df = pd.read_excel('data.xlsx')
df = df[['name', 'sport_type', 'description', 'coordinates']]
df
# Out:
#                                name        sport_type  \
# 0          Calistenics Park Salzach      Calisthenics
# 1      Calistenics Park Alpenstraße      Calisthenics
# 2   Beach Volleyball Donnenbergpark  Beach-Volleyball
# 3       Table tennis Donnenbergpark      Table-Tennis
# 4      Beach Volleyball Volksgarten  Beach-Volleyball
# 5                   Small Barmstein          Climbing
# 6           Gaisberg Klettergarten           Climbing
# 7   Basketball Court Donnenbergpark        Basketball
# 8         Calistenics Park Glanbach      Calisthenics
# 9         Basketball Court Glanbach        Basketball
# 10            Table tennis Glanbach      Table-Tennis
# 11        Slackline Park Glanspitze         Slackline
# 12          Table tennis Glanspitze      Table-Tennis
# 13          Soccer field Glanspitze            Soccer
# 14           Athletics Park Itzling         Athletics
#
#                                           description  \
# 0     Nice training area with shadow in the afternoon
# 1            Nice training area with sun all day long
# 2   Nice beach-volleyball field close to Almkanal ...
# 3   2 tables for table tennis next to each other i...
# 4   2 beach-volleyball fields perfect for tournaments
# 5   Sport climbing area with routes between grade ...
# 6   Sport climbing area with routes between grade ...
# 7                   Street ball court with one basket
# 8             Calisthenics Park next to the Glanbach
# 9                  Street ball court with two baskets
# 10                                          One table
# 11  Possibilities to set up several slacklines of ...
# 12  2 tables for table tennis next to each other n...
# 13                               2 small soccer goals
# 14              facilities for athletics, mostly open
#
#                                coordinates
# 0    47.80405845892574, 13.037556651700381
# 1   47.777922927461255, 13.064586591558372
# 2   47.788193993458634, 13.043390741193457
# 3      47.788262158184, 13.043052179790253
# 4    47.79640310970255, 13.060316436052583
# 5    47.68887536167374, 13.078379431299568
# 6   47.802816830965675, 13.105291346703961
# 7   47.788796706587554, 13.043210596940249
# 8    47.79042526760239, 13.020926157349237
# 9    47.78990455437094, 13.021223144692819
# 10  47.789444172595694, 13.021129991479302
# 11  47.821664924725255, 13.030851216391289
# 12   47.82082042176909, 13.030348958961179
# 13  47.820694861866066, 13.030763523338994
# 14   47.82095898863804, 13.037506002249131

# %% [markdown]
# Convert the data types of the coordinates column to tuples of floats

# %%
# convert coordinates into the list objects with float datatypes for the latitude and longitude
for i in range(0,len(df)):
    a = df['coordinates'][i].split(',')
    a = tuple(a)
    df['coordinates'][i] = (float(a[0]), float(a[1]))

# %% [markdown]
# Create a dictionary to get the coordinates by the name of the location:

# %%
df_dict = df.set_index('name')['coordinates'].to_dict()
#df_dict
# Out:
# {'Calistenics Park Salzach': (47.80405845892574, 13.037556651700381),
#  'Calistenics Park Alpenstraße': (47.777922927461255, 13.064586591558372),
#  'Beach Volleyball Donnenbergpark': (47.788193993458634, 13.043390741193457),
#  'Table tennis Donnenbergpark': (47.788262158184, 13.043052179790253),
#  'Beach Volleyball Volksgarten': (47.79640310970255, 13.060316436052583),
#  'Small Barmstein': (47.68887536167374, 13.078379431299568),
#  'Gaisberg Klettergarten ': (47.802816830965675, 13.105291346703961),
#  'Basketball Court Donnenbergpark': (47.788796706587554, 13.043210596940249),
#  'Calistenics Park Glanbach': (47.79042526760239, 13.020926157349237),
#  'Basketball Court Glanbach': (47.78990455437094, 13.021223144692819),
#  'Table tennis Glanbach': (47.789444172595694, 13.021129991479302),
#  'Slackline Park Glanspitze': (47.821664924725255, 13.030851216391289),
#  'Table tennis Glanspitze': (47.82082042176909, 13.030348958961179),
#  'Soccer field Glanspitze': (47.820694861866066, 13.030763523338994),
#  'Athletics Park Itzling': (47.82095898863804, 13.037506002249131)}

# %% [markdown]
# ### Map
#
# Calculate the center coordinates of the locations:

# %%
centerCoord = mf.getCenterCoordinates(df['coordinates'])
centerCoord
# Out:
# [47.79261618256844, 13.04456886464672]

# %% [markdown]
# Create the map:

# %%
mymap = mf.create_Map(centerCoord, zoom_start=11)

# %% [markdown]
# Add all data points:

# %%
pf.add_all_points(mymap, df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cd4eec46f3de266c63c5ade26264e6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cd4eec46f3de266c63c5ade26264e6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cd4eec46f3de266c63c5ade26264e6b = L.map(
#                 &quot;map_2cd4eec46f3de266c63c5ade26264e6b&quot;,
#                 {
#                     center: [47.79261618256844, 13.04456886464672],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2cd4eec46f3de266c63c5ade26264e6b);
#
#
#
#
#
#             var tile_layer_5076d0433ea7ff828c8524fe47556e0c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cd4eec46f3de266c63c5ade26264e6b);
#
#
#             var tile_layer_79d783d8365fcdfef366c8fc5cfb1917 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cd4eec46f3de266c63c5ade26264e6b);
#
#
#             var tile_layer_eb8fcaf38cc47a8070f5a3ae66fa0b04 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cd4eec46f3de266c63c5ade26264e6b);
#
#
#             var tile_layer_fc2c74f85252794a81358f807e789243 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cd4eec46f3de266c63c5ade26264e6b);
#
#
#             var tile_layer_ff79bb65654913bc185c205bff3e5bc6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cd4eec46f3de266c63c5ade26264e6b);
#
#
#             var tile_layer_fafa2710edf48338597520fee1f7755c = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u0

# %% [markdown]
# ### Routing
#
# Select starting coodinates:
# (by clicking anywhere in the map you can see its coordinates in a pop-up window)

# %%
start_coords = rf.starting_coord_by_user()
# Out:
# Please enter your starting coordinates here:
# Your starting coordinates: [47.7909, 13.1037]

# %%
def get_location_of(name):
    return df_dict[name]

# %% [markdown]
# Select your destination (one of the locations):

# %%
end_coords = get_location_of('Basketball Court Glanbach')
end_coords
# Out:
# (47.78990455437094, 13.021223144692819)

# %% [markdown]
# Download the necessary graph:

# %%
#download the OSM network around our center coordinates with 15km radius
# this can take a couple of minutes
# set radius:
radius = 10000 

#different types: 'all', 'bike', 'drive', 'walk',  
# all
#graph_all = ox.graph_from_point(tuple(centerCoord), dist = radius, network_type='all')
# bike
graph_bike = ox.graph_from_point(tuple(centerCoord), dist = radius, network_type='bike')
# walk
#graph_walk = ox.graph_from_point(tuple(centerCoord), dist = radius, network_type='walk')
# drive
#graph_drive = ox.graph_from_point(tuple(centerCoord), dist = radius, network_type='drive')

# %% [markdown]
# Calculate and plot the route between your starting and end point:

# %%
rf.calculate_route(map = mymap, start_coords=start_coords, end_coords=end_coords, graph_type=graph_bike)
# Out:
# The length of your route is  7.9 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81d38cdb434f8d3599dd020d9e3e2220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81d38cdb434f8d3599dd020d9e3e2220&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81d38cdb434f8d3599dd020d9e3e2220 = L.map(
#                 &quot;map_81d38cdb434f8d3599dd020d9e3e2220&quot;,
#                 {
#                     center: [47.79261618256844, 13.04456886464672],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_81d38cdb434f8d3599dd020d9e3e2220);
#
#
#
#
#
#             var tile_layer_40758a3657e41f21aa99f1a80aad0333 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81d38cdb434f8d3599dd020d9e3e2220);
#
#
#             var tile_layer_b493296d089c3ed22158ad28cec74cea = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81d38cdb434f8d3599dd020d9e3e2220);
#
#
#             var tile_layer_02550fd6985dc474714afa2a423410a5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81d38cdb434f8d3599dd020d9e3e2220);
#
#
#             var tile_layer_51918d2827d84533a3dadb24f1c684e3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81d38cdb434f8d3599dd020d9e3e2220);
#
#
#             var tile_layer_7a510acee9961389accca474b9132186 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81d38cdb434f8d3599dd020d9e3e2220);
#
#
#             var tile_layer_56c642b605e32a3172c9264b8a6ef2e2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u0
